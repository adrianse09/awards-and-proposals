# %%
import pandas as pd

# Specify the correct file paths
file_path_awards = "C:\\Users\\abuitronboada\\Box\\CombineNode\\Jupyter\\Awards_report.xlsx"
file_path_proposals = "C:\\Users\\abuitronboada\\Box\\CombineNode\\Jupyter\\Proposals_report.xlsx"

# Read the Excel files into DataFrames
awards_df = pd.read_excel(file_path_awards)
proposals_df = pd.read_excel(file_path_proposals)

# Display the first few rows to verify the data
print("Awards DataFrame:")
print(awards_df.head())
print("\nProposals DataFrame:")
print(proposals_df.head())
# Out:
# Sheets in the workbook: ['Awards', 'Proposals']

# %%
from openpyxl import Workbook

# Create a Workbook object
workbook = Workbook()

# Create a worksheet for awards
worksheet_awards = workbook.active
worksheet_awards.title = "Awards"

# Create a worksheet for proposals
worksheet_proposals = workbook.create_sheet(title="Proposals")

# Verify the sheets are created
print("Sheets in the workbook:", workbook.sheetnames)

# %%
# Specify the titles for the Awards sheet
awards_titles = [
    "Project Number",
    "Award Lead Pi",
    "Project Title",
    "Sponsor",
    "Award Amount",
    "Award Notice Date"
]

# Specify the titles for the Proposals sheet
proposals_titles = [
    "Proposal Number",
    "Proposal Lead Pi Name",
    "Proposal Specialist",
    "Owner",
    "Proposal Title",
    "Proposal Sponsor",
    "Proposal Type",
    "Proposal Status",
    "Submitted to Sponsor",
    "Total Amount Proposed"
]

# Write column titles to the Awards sheet
worksheet_awards.append(awards_titles)

# Write column titles to the Proposals sheet
worksheet_proposals.append(proposals_titles)

# Write data from awards_df to the Awards sheet
for idx, row in awards_df.iterrows():
    worksheet_awards.append(list(row))

# Write data from proposals_df to the Proposals sheet
for idx, row in proposals_df.iterrows():
    worksheet_proposals.append(list(row))

# Verify data is written
print("Data written to Awards sheet:")
for row in worksheet_awards.iter_rows(min_row=1, max_row=5, values_only=True):
    print(row)

print("\nData written to Proposals sheet:")
for row in worksheet_proposals.iter_rows(min_row=1, max_row=5, values_only=True):
    print(row)
# Out:
# Data written to Awards sheet:
# ('Project Number', 'Award Lead Pi', 'Project Title', 'Sponsor', 'Award Amount', 'Award Notice Date')
# ('A24-0135', 'Shahar Sukenik', 'BII: Life without water: protecting macromolecules, cells, and organisms during desiccation and rehydration across kingdoms of life', '8832 - MICHIGAN STATE UNIVERSITY', 75252, Timestamp('2024-04-08 00:00:00'))
# ('A24-0137', 'LAURA HAMILTON', 'Wealth-Based Financial Aid', 'FEAE - College Futures Foundation', 200000, Timestamp('2024-04-09 00:00:00'))
# (None, None, None, None, None, None)
# (None, None, None, None, None, None)
#
# Data written to Proposals sheet:
# ('Proposal Number', 'Proposal Lead Pi Name', 'Proposal Specialist', 'Owner', 'Proposal Title', 'Proposal Sponsor', 'Proposal Type', 'Proposal Status', 'Submitted to Sponsor', 'Total Amount Proposed')
# ('24-0367', 'Young,Maria-Elena', "Bryan O'Neill", 'Silas Verrinder', 'Understanding immigration-related health care access disparities for victims of intimate partner violence', '4669 - National Institue on Minority Health and Health Disparities (NIMHD) - NIH', 'Resubmission', 'Submitted to Sponsor', Timestamp('2024-04-08 00:00:00'), 121717)
# ('24-0429', 'Vang,Ma', 'Wendy Lopez', 'Travis Perry', 'People-making Pedagogy: Intergenerational Knowledge and Reconfiguring the Human', '5280 - NFAH HUMANITIES, NATIONAL ENDOWMENT FOR THE - NEH', 'Late Submission', 'Submitted to Sponsor', Timestamp('2024-04-10 00:00:00'), 60000)
# ('24-0409', 'HAMILTON,LAURA', 'Wendy Lopez', 'Rebekah Johnson', 'The Dismantling of Postsecondary DEI: Organizational Responses and Identifying Strategies for  Resistance', '8514 - WILLIAM T. GRANT FOUNDATION', 'New', 'Submitted to Sponsor', Timestamp('2024-04-12 00:00:00'), 600000)
# ('24-0403', 'BURKE,NANCY', 'Wendy Lopez', 'Travis Perry', 'Exploration of Punjabi farm owners and workers pesticide exposure and care seeking', '6529 - OFFICE OF ENVIRONMENTAL HEALTH HAZARD ASSESSMENT - OEHHA', 'New', 'Submitted to Sponsor', Timestamp('2024-04-12 00:00:00'), 49991)

# %%
# Save the workbook
workbook.save('C:\\Users\\abuitronboada\\Box\\CombineNode\\Jupyter\\combined.xlsx')

print("Workbook saved as 'combined.xlsx'.")
# Out:
# Workbook saved as 'combined.xlsx'.

# %%
from openpyxl import load_workbook

# Load the workbook
workbook = load_workbook('C:\\Users\\abuitronboada\\Box\\CombineNode\\Jupyter\\combined.xlsx')
worksheet_awards = workbook['Awards']
worksheet_proposals = workbook['Proposals']

# Initialize variables to store the total amounts
total_award_amount = 0
proposals_total = 0

# Iterate over the rows in the "Awards" sheet starting from the second row
for row in worksheet_awards.iter_rows(min_row=2, values_only=True):
    award_amount = row[4]  # Assuming "Award Amount" is the fifth column (index 4)
    if isinstance(award_amount, (int, float)):
        total_award_amount += award_amount

# Iterate over the rows in the "Proposals" sheet starting from the second row
for row in worksheet_proposals.iter_rows(min_row=2, values_only=True):
    proposals_amount = row[-1]  # Assuming "Total Amount Proposed" is the last column
    if isinstance(proposals_amount, (int, float)):
        proposals_total += proposals_amount

# Print the total amounts
print("Total Award Amount:", total_award_amount)
print("Total Proposals Amount:", proposals_total)
# Out:
# Total Award Amount: 275252
# Total Proposals Amount: 831708

# %%
import pandas as pd

# Load the Awards sheet from the combined.xlsx file
combined_awards_df = pd.read_excel('C:\\Users\\abuitronboada\\Box\\CombineNode\\Jupyter\\combined.xlsx', sheet_name='Awards')

# Load the Proposals sheet from the combined.xlsx file
combined_proposals_df = pd.read_excel('C:\\Users\\abuitronboada\\Box\\CombineNode\\Jupyter\\combined.xlsx', sheet_name='Proposals')

# Display the first few rows of each sheet
print("Awards Sheet:")
display(combined_awards_df.head())

print("\nProposals Sheet:")
display(combined_proposals_df.head())
# Out:
# Awards Sheet:
#   Project Number   Award Lead Pi  \
# 0       A24-0135  Shahar Sukenik
# 1       A24-0137  LAURA HAMILTON
#
#                                        Project Title  \
# 0  BII: Life without water: protecting macromolec...
# 1                         Wealth-Based Financial Aid
#
#                              Sponsor  Award Amount Award Notice Date
# 0   8832 - MICHIGAN STATE UNIVERSITY         75252        2024-04-08
# 1  FEAE - College Futures Foundation        200000        2024-04-09
# Proposals Sheet:
#   Proposal Number Proposal Lead Pi Name Proposal Specialist            Owner  \
# 0         24-0367     Young,Maria-Elena       Bryan O'Neill  Silas Verrinder
# 1         24-0429               Vang,Ma         Wendy Lopez     Travis Perry
# 2         24-0409        HAMILTON,LAURA         Wendy Lopez  Rebekah Johnson
# 3         24-0403           BURKE,NANCY         Wendy Lopez     Travis Perry
#
#                                       Proposal Title  \
# 0  Understanding immigration-related health care ...
# 1  People-making Pedagogy: Intergenerational Know...
# 2  The Dismantling of Postsecondary DEI: Organiza...
# 3  Exploration of Punjabi farm owners and workers...
#
#                                     Proposal Sponsor    Proposal Type  \
# 0  4669 - National Institue on Minority Health an...     Resubmission
# 1  5280 - NFAH HUMANITIES, NATIONAL ENDOWMENT FOR...  Late Submission
# 2                 8514 - WILLIAM T. GRANT FOUNDATION              New
# 3  6529 - OFFICE OF ENVIRONMENTAL HEALTH HAZARD A...              New
#
#         Proposal Status Submitted to Sponsor  Total Amount Proposed
# 0  Submitted to Sponsor           2024-04-08                 121717
# 1  Submitted to Sponsor           2024-04-10                  60000
# 2  Submitted to Sponsor           2024-04-12                 600000
# 3  Submitted to Sponsor           2024-04-12                  49991

# %%
#Total Code
import pandas as pd
from openpyxl import Workbook, load_workbook

# Specify the correct file paths
file_path_awards = "C:\\Users\\abuitronboada\\Box\\CombineNode\\Jupyter\\Awards_report.xlsx"
file_path_proposals = "C:\\Users\\abuitronboada\\Box\\CombineNode\\Jupyter\\Proposals_report.xlsx"

# Read the Excel files into DataFrames
awards_df = pd.read_excel(file_path_awards)
proposals_df = pd.read_excel(file_path_proposals)

# Create a Workbook object
workbook = Workbook()

# Create a worksheet for awards
worksheet_awards = workbook.active
worksheet_awards.title = "Awards"

# Create a worksheet for proposals
worksheet_proposals = workbook.create_sheet(title="Proposals")

# Specify the titles for the Awards sheet
awards_titles = [
    "Project Number",
    "Award Lead Pi",
    "Project Title",
    "Sponsor",
    "Award Amount",
    "Award Notice Date"
]

# Specify the titles for the Proposals sheet
proposals_titles = [
    "Proposal Number",
    "Proposal Lead Pi Name",
    "Proposal Specialist",
    "Owner",
    "Proposal Title",
    "Proposal Sponsor",
    "Proposal Type",
    "Proposal Status",
    "Submitted to Sponsor",
    "Total Amount Proposed"
]

# Write column titles to the Awards sheet
worksheet_awards.append(awards_titles)

# Write column titles to the Proposals sheet
worksheet_proposals.append(proposals_titles)

# Write data from awards_df to the Awards sheet
for idx, row in awards_df.iterrows():
    worksheet_awards.append(list(row))

# Write data from proposals_df to the Proposals sheet
for idx, row in proposals_df.iterrows():
    worksheet_proposals.append(list(row))

# Save the workbook
workbook.save('C:\\Users\\abuitronboada\\Box\\CombineNode\\Jupyter\\combined.xlsx')
print("Workbook saved as 'combined.xlsx'.")

# Load the workbook to calculate the total award amount
workbook = load_workbook('C:\\Users\\abuitronboada\\Box\\CombineNode\\Jupyter\\combined.xlsx')
worksheet_awards = workbook['Awards']
worksheet_proposals = workbook['Proposals']

# Initialize variables to store the total amounts
total_award_amount = 0
proposals_total = 0

# Iterate over the rows in the "Awards" sheet starting from the second row
for row in worksheet_awards.iter_rows(min_row=2, values_only=True):
    award_amount = row[4]  # Assuming "Award Amount" is the fifth column (index 4)
    if isinstance(award_amount, (int, float)):
        total_award_amount += award_amount

# Iterate over the rows in the "Proposals" sheet starting from the second row
for row in worksheet_proposals.iter_rows(min_row=2, values_only=True):
    proposals_amount = row[-1]  # Assuming "Total Amount Proposed" is the last column
    if isinstance(proposals_amount, (int, float)):
        proposals_total += proposals_amount

# Print the total amounts
print("Total Award Amount:", total_award_amount)
print("Total Proposals Amount:", proposals_total)

# Load the Awards sheet from the combined.xlsx file
combined_awards_df = pd.read_excel('C:\\Users\\abuitronboada\\Box\\CombineNode\\Jupyter\\combined.xlsx', sheet_name='Awards')

# Load the Proposals sheet from the combined.xlsx file
combined_proposals_df = pd.read_excel('C:\\Users\\abuitronboada\\Box\\CombineNode\\Jupyter\\combined.xlsx', sheet_name='Proposals')

# Display the first few rows of each sheet
print("Awards Sheet:")
display(combined_awards_df.head())

print("\nProposals Sheet:")
display(combined_proposals_df.head())
# Out:
# Workbook saved as 'combined.xlsx'.
# Total Award Amount: 275252
# Total Proposals Amount: 831708
# Awards Sheet:
#   Project Number   Award Lead Pi  \
# 0       A24-0135  Shahar Sukenik
# 1       A24-0137  LAURA HAMILTON
#
#                                        Project Title  \
# 0  BII: Life without water: protecting macromolec...
# 1                         Wealth-Based Financial Aid
#
#                              Sponsor  Award Amount Award Notice Date
# 0   8832 - MICHIGAN STATE UNIVERSITY         75252        2024-04-08
# 1  FEAE - College Futures Foundation        200000        2024-04-09
# Proposals Sheet:
#   Proposal Number Proposal Lead Pi Name Proposal Specialist            Owner  \
# 0         24-0367     Young,Maria-Elena       Bryan O'Neill  Silas Verrinder
# 1         24-0429               Vang,Ma         Wendy Lopez     Travis Perry
# 2         24-0409        HAMILTON,LAURA         Wendy Lopez  Rebekah Johnson
# 3         24-0403           BURKE,NANCY         Wendy Lopez     Travis Perry
#
#                                       Proposal Title  \
# 0  Understanding immigration-related health care ...
# 1  People-making Pedagogy: Intergenerational Know...
# 2  The Dismantling of Postsecondary DEI: Organiza...
# 3  Exploration of Punjabi farm owners and workers...
#
#                                     Proposal Sponsor    Proposal Type  \
# 0  4669 - National Institue on Minority Health an...     Resubmission
# 1  5280 - NFAH HUMANITIES, NATIONAL ENDOWMENT FOR...  Late Submission
# 2                 8514 - WILLIAM T. GRANT FOUNDATION              New
# 3  6529 - OFFICE OF ENVIRONMENTAL HEALTH HAZARD A...              New
#
#         Proposal Status Submitted to Sponsor  Total Amount Proposed
# 0  Submitted to Sponsor           2024-04-08                 121717
# 1  Submitted to Sponsor           2024-04-10                  60000
# 2  Submitted to Sponsor           2024-04-12                 600000
# 3  Submitted to Sponsor           2024-04-12                  49991
